-- %%
SELECT *
FROM retail.sales.retail_sales_dataset_1; 

SELECT *
FROM retail.sales.retail_sales_dataset_1
LIMIT 20;

SELECT DISTINCT(gender)
FROM retail.sales.retail_sales_dataset_1;

SELECT DISTINCT(`product category`)
FROM retail.sales.retail_sales_dataset_1;

SELECT MIN(Age),MAX(Age)
FROM retail.sales.retail_sales_dataset_1; 

SELECT SUM(`total amount`) AS total_revenue
FROM retail.sales.retail_sales_dataset_1; 

SELECT *
FROM retail.sales.retail_sales_dataset_1
WHERE (`Price per unit`) > 500;

SELECT DISTINCT(`product category`), `price per unit`
FROM retail.sales.retail_sales_dataset_1
WHERE `product category`= 'Beauty'ORDER BY `price per unit` DESC;

SELECT DISTINCT(`Product Category`),
        `Price per Unit`
FROM  retail.sales.retail_sales_dataset_1
WHERE `Product Category` IN ('Beauty', 'Electronics') ORDER BY `Price per Unit` DESC;
